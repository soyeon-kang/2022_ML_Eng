# %% [markdown]
# <a href="https://colab.research.google.com/github/soyeon-kang/2022_ML_Eng/blob/main/%5BDay_5_1%5D_Edge_detection_using_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Edge Detection with PyTorch

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os, time
import os.path as osp
import math
import numpy as np
import pandas as pd
from PIL import Image
import pylab
import matplotlib.cm as cm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# %%
# !wget http://mftp.mmcheng.net/liuyun/rcf/data/HED-BSDS.tar.gz
# !tar -zxvf HED-BSDS.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/119082.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/35058.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/3096.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/108082.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/80099.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/117054.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/241048.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/155060.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/253055.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/241004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/42012.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/304034.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/285036.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/175043.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/23025.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/216053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/286092.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/292066.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/134008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/196073.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/69040.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/86000.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/271031.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/176039.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/102061.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/43083.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/134035.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/46076.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/100098.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/105053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/48055.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/65132.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/260081.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/170057.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/61086.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/126039.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/28075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/71046.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/21077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/301007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/232038.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/198023.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/126007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/45077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/374020.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/173036.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/210088.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/78004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/220075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/300091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/65074.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/33039.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/296059.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/285079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/101087.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/59078.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/181079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/65033.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/209070.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/198054.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/78019.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/295087.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/22090.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/109034.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/43070.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/159008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/108070.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/24063.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/103070.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/219090.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/157055.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/15004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/156065.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/353013.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/187003.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/19021.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/87065.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/242078.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/153093.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/20008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/160068.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/66053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/27059.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/277095.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/365025.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/55075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/254054.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/65010.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/12084.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/182053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/245051.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/164074.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/38092.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/314016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/60079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/122048.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/33066.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/66039.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/178054.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/138078.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/299091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/166081.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/306005.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/41025.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/196015.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/239096.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/124084.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/198004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/249061.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/148089.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/22093.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/326038.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/188005.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/172032.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/16052.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/361010.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/361084.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/187083.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/227092.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/181018.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/8023.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/113016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/187029.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/148026.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/208001.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/35070.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/231015.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/104022.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/106025.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/181091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/118035.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/293029.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/23080.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/112082.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/85048.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/69020.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/106020.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/176019.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/385028.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/134052.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/144067.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/105019.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/101085.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/187039.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/175032.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/271008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/61060.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/66075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/86016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/376020.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/45096.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/246053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/54082.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/140055.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/239007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/113044.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/147091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/183055.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/38082.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/103041.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/16077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/55067.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/372047.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/41069.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/227046.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/135069.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/100080.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/260058.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/42078.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/216041.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/113009.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/351093.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/176035.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/299086.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/55073.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/145053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/274007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/23084.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/317080.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/54005.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/167062.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/2092.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/143090.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/223061.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/35010.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/291000.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/100075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/216081.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/374067.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/76002.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/311081.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/388016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/90076.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/22013.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/43074.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/108073.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/157036.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/311068.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/35008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/225017.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/163085.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/37073.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/304074.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/376043.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/145086.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/271035.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/105025.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/202012.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/368016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/170054.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/8049.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/310007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/268002.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/249087.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/97017.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/42049.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/97033.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/183087.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/238011.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/95006.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/108041.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/24004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/69015.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/159029.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/216066.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/130026.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/65019.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/376001.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/62096.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/15088.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/189003.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/229036.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/159045.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/159091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/151087.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/246016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/138032.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/56028.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/302008.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/24077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/147062.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/140075.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/26031.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/156079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/109053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/302003.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/163014.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/188091.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/123074.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/197017.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/365073.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/14037.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/86068.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/28096.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/189011.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/247085.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/145014.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/67079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/92059.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/236037.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/135037.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/94079.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/76053.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/106024.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/189080.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/58060.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/68077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/187071.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/89072.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/153077.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/323016.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/309004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/368078.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/188063.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/296007.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/236017.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/169012.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/25098.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/118020.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/8143.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/41004.png
# HED-BSDS/train/aug_gt_scale_0.5/315.0_1_0/385039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/35091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/41033.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/253036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/370036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/12074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/130034.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/227040.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/108005.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/254033.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/12003.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/207056.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/161062.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/147021.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/42044.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/167083.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/87046.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/253027.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/163062.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/119082.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/35058.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/3096.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/108082.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/80099.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/117054.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/241048.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/155060.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/253055.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/241004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/42012.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/304034.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/285036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/175043.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/23025.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/216053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/286092.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/292066.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/134008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/196073.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/69040.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/86000.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/271031.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/176039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/102061.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/43083.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/134035.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/46076.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/100098.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/105053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/48055.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/65132.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/260081.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/170057.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/61086.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/126039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/28075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/71046.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/21077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/301007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/232038.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/198023.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/126007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/45077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/374020.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/173036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/210088.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/78004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/220075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/300091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/65074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/33039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/296059.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/285079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/101087.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/59078.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/181079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/65033.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/209070.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/198054.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/78019.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/295087.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/22090.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/109034.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/43070.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/159008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/108070.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/24063.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/103070.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/219090.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/157055.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/15004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/156065.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/353013.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/187003.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/19021.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/87065.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/242078.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/153093.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/20008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/160068.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/66053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/27059.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/277095.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/365025.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/55075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/254054.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/65010.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/12084.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/182053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/245051.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/164074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/38092.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/314016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/60079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/122048.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/33066.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/66039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/178054.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/138078.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/299091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/166081.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/306005.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/41025.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/196015.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/239096.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/124084.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/198004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/249061.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/148089.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/22093.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/326038.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/188005.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/172032.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/16052.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/361010.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/361084.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/187083.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/227092.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/181018.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/8023.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/113016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/187029.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/148026.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/208001.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/35070.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/231015.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/104022.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/106025.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/181091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/118035.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/293029.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/23080.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/112082.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/85048.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/69020.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/106020.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/176019.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/385028.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/134052.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/144067.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/105019.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/101085.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/187039.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/175032.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/271008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/61060.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/66075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/86016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/376020.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/45096.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/246053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/54082.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/140055.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/239007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/113044.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/147091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/183055.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/38082.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/103041.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/16077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/55067.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/372047.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/41069.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/227046.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/135069.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/100080.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/260058.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/42078.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/216041.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/113009.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/351093.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/176035.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/299086.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/55073.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/145053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/274007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/23084.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/317080.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/54005.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/167062.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/2092.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/143090.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/223061.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/35010.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/291000.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/100075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/216081.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/374067.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/76002.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/311081.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/388016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/90076.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/22013.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/43074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/108073.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/157036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/311068.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/35008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/225017.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/163085.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/37073.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/304074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/376043.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/145086.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/271035.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/105025.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/202012.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/368016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/170054.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/8049.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/310007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/268002.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/249087.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/97017.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/42049.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/97033.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/183087.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/238011.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/95006.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/108041.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/24004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/69015.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/159029.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/216066.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/130026.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/65019.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/376001.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/62096.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/15088.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/189003.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/229036.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/159045.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/159091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/151087.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/246016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/138032.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/56028.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/302008.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/24077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/147062.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/140075.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/26031.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/156079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/109053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/302003.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/163014.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/188091.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/123074.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/197017.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/365073.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/14037.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/86068.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/28096.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/189011.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/247085.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/145014.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/67079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/92059.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/236037.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/135037.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/94079.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/76053.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/106024.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/189080.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/58060.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/68077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/187071.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/89072.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/153077.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/323016.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/309004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/368078.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/188063.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/296007.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/236017.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/169012.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/25098.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/118020.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/8143.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/41004.png
# HED-BSDS/train/aug_gt_scale_0.5/67.5_1_1/385039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/35091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/41033.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/253036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/370036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/12074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/130034.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/227040.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/108005.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/254033.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/12003.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/207056.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/161062.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/147021.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/42044.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/167083.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/87046.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/253027.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/163062.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/119082.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/35058.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/3096.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/108082.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/80099.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/117054.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/241048.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/155060.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/253055.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/241004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/42012.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/304034.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/285036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/175043.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/23025.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/216053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/286092.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/292066.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/134008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/196073.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/69040.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/86000.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/271031.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/176039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/102061.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/43083.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/134035.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/46076.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/100098.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/105053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/48055.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/65132.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/260081.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/170057.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/61086.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/126039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/28075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/71046.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/21077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/301007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/232038.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/198023.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/126007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/45077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/374020.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/173036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/210088.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/78004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/220075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/300091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/65074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/33039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/296059.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/285079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/101087.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/59078.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/181079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/65033.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/209070.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/198054.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/78019.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/295087.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/22090.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/109034.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/43070.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/159008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/108070.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/24063.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/103070.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/219090.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/157055.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/15004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/156065.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/353013.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/187003.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/19021.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/87065.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/242078.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/153093.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/20008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/160068.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/66053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/27059.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/277095.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/365025.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/55075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/254054.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/65010.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/12084.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/182053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/245051.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/164074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/38092.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/314016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/60079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/122048.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/33066.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/66039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/178054.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/138078.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/299091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/166081.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/306005.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/41025.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/196015.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/239096.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/124084.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/198004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/249061.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/148089.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/22093.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/326038.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/188005.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/172032.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/16052.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/361010.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/361084.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/187083.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/227092.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/181018.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/8023.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/113016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/187029.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/148026.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/208001.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/35070.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/231015.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/104022.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/106025.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/181091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/118035.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/293029.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/23080.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/112082.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/85048.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/69020.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/106020.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/176019.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/385028.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/134052.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/144067.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/105019.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/101085.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/187039.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/175032.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/271008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/61060.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/66075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/86016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/376020.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/45096.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/246053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/54082.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/140055.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/239007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/113044.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/147091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/183055.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/38082.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/103041.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/16077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/55067.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/372047.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/41069.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/227046.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/135069.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/100080.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/260058.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/42078.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/216041.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/113009.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/351093.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/176035.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/299086.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/55073.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/145053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/274007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/23084.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/317080.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/54005.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/167062.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/2092.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/143090.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/223061.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/35010.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/291000.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/100075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/216081.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/374067.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/76002.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/311081.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/388016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/90076.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/22013.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/43074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/108073.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/157036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/311068.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/35008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/225017.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/163085.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/37073.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/304074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/376043.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/145086.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/271035.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/105025.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/202012.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/368016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/170054.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/8049.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/310007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/268002.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/249087.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/97017.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/42049.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/97033.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/183087.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/238011.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/95006.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/108041.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/24004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/69015.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/159029.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/216066.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/130026.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/65019.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/376001.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/62096.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/15088.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/189003.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/229036.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/159045.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/159091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/151087.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/246016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/138032.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/56028.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/302008.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/24077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/147062.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/140075.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/26031.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/156079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/109053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/302003.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/163014.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/188091.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/123074.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/197017.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/365073.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/14037.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/86068.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/28096.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/189011.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/247085.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/145014.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/67079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/92059.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/236037.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/135037.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/94079.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/76053.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/106024.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/189080.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/58060.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/68077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/187071.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/89072.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/153077.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/323016.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/309004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/368078.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/188063.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/296007.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/236017.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/169012.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/25098.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/118020.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/8143.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/41004.png
# HED-BSDS/train/aug_gt_scale_0.5/202.5_1_1/385039.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/35091.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/41033.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/253036.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/370036.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/12074.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/130034.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/227040.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/108005.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/254033.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/12003.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/207056.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/161062.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/147021.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/42044.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/167083.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/87046.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/253027.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/163062.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/119082.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/35058.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/3096.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/108082.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/80099.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/117054.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/241048.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/155060.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/253055.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/241004.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/42012.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/304034.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/285036.png
# HED-BSDS/train/aug_gt_scale_0.5/247.5_1_0/175043.png
# ...
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/157055.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/15004.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/156065.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/353013.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/187003.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/19021.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/87065.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/242078.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/153093.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/20008.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/160068.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/66053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/27059.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/277095.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/365025.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/55075.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/254054.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/65010.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/12084.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/182053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/245051.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/164074.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/38092.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/314016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/60079.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/122048.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/33066.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/66039.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/178054.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/138078.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/299091.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/166081.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/306005.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/41025.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/196015.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/239096.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/124084.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/198004.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/249061.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/148089.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/22093.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/326038.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/188005.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/172032.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/16052.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/361010.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/361084.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/187083.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/227092.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/181018.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/8023.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/113016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/187029.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/148026.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/208001.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/35070.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/231015.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/104022.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/106025.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/181091.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/118035.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/293029.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/23080.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/112082.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/85048.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/69020.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/106020.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/176019.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/385028.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/134052.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/144067.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/105019.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/101085.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/187039.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/175032.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/271008.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/61060.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/66075.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/86016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/376020.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/45096.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/246053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/54082.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/140055.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/239007.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/113044.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/147091.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/183055.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/38082.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/103041.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/16077.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/55067.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/372047.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/41069.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/227046.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/135069.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/100080.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/260058.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/42078.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/216041.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/113009.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/351093.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/176035.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/299086.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/55073.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/145053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/274007.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/23084.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/317080.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/54005.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/167062.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/2092.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/143090.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/223061.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/35010.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/291000.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/100075.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/216081.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/374067.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/76002.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/311081.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/388016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/90076.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/22013.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/43074.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/108073.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/157036.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/311068.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/35008.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/225017.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/163085.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/37073.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/304074.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/376043.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/145086.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/271035.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/105025.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/202012.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/368016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/170054.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/8049.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/310007.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/268002.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/249087.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/97017.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/42049.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/97033.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/183087.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/238011.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/95006.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/108041.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/24004.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/69015.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/159029.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/216066.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/130026.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/65019.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/376001.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/62096.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/15088.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/189003.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/229036.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/159045.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/159091.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/151087.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/246016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/138032.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/56028.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/302008.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/24077.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/147062.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/140075.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/26031.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/156079.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/109053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/302003.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/163014.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/188091.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/123074.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/197017.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/365073.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/14037.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/86068.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/28096.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/189011.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/247085.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/145014.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/67079.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/92059.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/236037.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/135037.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/94079.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/76053.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/106024.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/189080.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/58060.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/68077.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/187071.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/89072.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/153077.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/323016.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/309004.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/368078.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/188063.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/296007.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/236017.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/169012.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/25098.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/118020.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/8143.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/41004.png
# HED-BSDS/train/aug_gt_scale_0.5/22.5_1_0/385039.png
# HED-BSDS/test.lst
# HED-BSDS/test/
# HED-BSDS/test/100007.jpg
# HED-BSDS/test/14092.jpg
# HED-BSDS/test/43051.jpg
# HED-BSDS/test/15011.jpg
# HED-BSDS/test/103006.jpg
# HED-BSDS/test/140006.jpg
# HED-BSDS/test/140088.jpg
# HED-BSDS/test/41085.jpg
# HED-BSDS/test/118015.jpg
# HED-BSDS/test/92014.jpg
# HED-BSDS/test/285022.jpg
# HED-BSDS/test/334025.jpg
# HED-BSDS/test/267036.jpg
# HED-BSDS/test/146074.jpg
# HED-BSDS/test/306052.jpg
# HED-BSDS/test/81066.jpg
# HED-BSDS/test/36046.jpg
# HED-BSDS/test/183066.jpg
# HED-BSDS/test/141048.jpg
# HED-BSDS/test/81090.jpg
# HED-BSDS/test/372019.jpg
# HED-BSDS/test/147077.jpg
# HED-BSDS/test/281017.jpg
# HED-BSDS/test/147080.jpg
# HED-BSDS/test/159002.jpg
# HED-BSDS/test/296028.jpg
# HED-BSDS/test/109055.jpg
# HED-BSDS/test/69022.jpg
# HED-BSDS/test/130066.jpg
# HED-BSDS/test/45000.jpg
# HED-BSDS/test/176051.jpg
# HED-BSDS/test/196088.jpg
# HED-BSDS/test/61034.jpg
# HED-BSDS/test/49024.jpg
# HED-BSDS/test/223060.jpg
# HED-BSDS/test/164046.jpg
# HED-BSDS/test/157087.jpg
# HED-BSDS/test/128035.jpg
# HED-BSDS/test/250047.jpg
# HED-BSDS/test/69007.jpg
# HED-BSDS/test/157032.jpg
# HED-BSDS/test/226033.jpg
# HED-BSDS/test/175083.jpg
# HED-BSDS/test/81095.jpg
# HED-BSDS/test/344010.jpg
# HED-BSDS/test/238025.jpg
# HED-BSDS/test/268074.jpg
# HED-BSDS/test/159022.jpg
# HED-BSDS/test/209021.jpg
# HED-BSDS/test/29030.jpg
# HED-BSDS/test/217013.jpg
# HED-BSDS/test/5096.jpg
# HED-BSDS/test/16004.jpg
# HED-BSDS/test/48025.jpg
# HED-BSDS/test/207049.jpg
# HED-BSDS/test/118031.jpg
# HED-BSDS/test/145079.jpg
# HED-BSDS/test/65084.jpg
# HED-BSDS/test/230098.jpg
# HED-BSDS/test/296058.jpg
# HED-BSDS/test/226022.jpg
# HED-BSDS/test/208078.jpg
# HED-BSDS/test/385022.jpg
# HED-BSDS/test/28083.jpg
# HED-BSDS/test/289011.jpg
# HED-BSDS/test/346016.jpg
# HED-BSDS/test/15062.jpg
# HED-BSDS/test/145059.jpg
# HED-BSDS/test/225022.jpg
# HED-BSDS/test/202000.jpg
# HED-BSDS/test/120093.jpg
# HED-BSDS/test/130014.jpg
# HED-BSDS/test/17067.jpg
# HED-BSDS/test/393035.jpg
# HED-BSDS/test/189013.jpg
# HED-BSDS/test/80090.jpg
# HED-BSDS/test/120003.jpg
# HED-BSDS/test/100039.jpg
# HED-BSDS/test/309040.jpg
# HED-BSDS/test/368037.jpg
# HED-BSDS/test/106047.jpg
# HED-BSDS/test/78098.jpg
# HED-BSDS/test/189006.jpg
# HED-BSDS/test/163004.jpg
# HED-BSDS/test/103078.jpg
# HED-BSDS/test/279005.jpg
# HED-BSDS/test/187099.jpg
# HED-BSDS/test/41006.jpg
# HED-BSDS/test/335088.jpg
# HED-BSDS/test/187058.jpg
# HED-BSDS/test/80085.jpg
# HED-BSDS/test/306051.jpg
# HED-BSDS/test/79073.jpg
# HED-BSDS/test/10081.jpg
# HED-BSDS/test/107072.jpg
# HED-BSDS/test/232076.jpg
# HED-BSDS/test/206097.jpg
# HED-BSDS/test/168084.jpg
# HED-BSDS/test/35028.jpg
# HED-BSDS/test/207038.jpg
# HED-BSDS/test/247003.jpg
# HED-BSDS/test/326025.jpg
# HED-BSDS/test/228076.jpg
# HED-BSDS/test/235098.jpg
# HED-BSDS/test/104010.jpg
# HED-BSDS/test/189029.jpg
# HED-BSDS/test/290035.jpg
# HED-BSDS/test/161045.jpg
# HED-BSDS/test/16068.jpg
# HED-BSDS/test/108036.jpg
# HED-BSDS/test/134067.jpg
# HED-BSDS/test/160006.jpg
# HED-BSDS/test/108069.jpg
# HED-BSDS/test/196040.jpg
# HED-BSDS/test/3063.jpg
# HED-BSDS/test/188025.jpg
# HED-BSDS/test/70011.jpg
# HED-BSDS/test/107014.jpg
# HED-BSDS/test/23050.jpg
# HED-BSDS/test/117025.jpg
# HED-BSDS/test/41096.jpg
# HED-BSDS/test/259060.jpg
# HED-BSDS/test/14085.jpg
# HED-BSDS/test/258089.jpg
# HED-BSDS/test/277053.jpg
# HED-BSDS/test/64061.jpg
# HED-BSDS/test/160067.jpg
# HED-BSDS/test/100099.jpg
# HED-BSDS/test/217090.jpg
# HED-BSDS/test/134049.jpg
# HED-BSDS/test/107045.jpg
# HED-BSDS/test/226060.jpg
# HED-BSDS/test/108004.jpg
# HED-BSDS/test/189096.jpg
# HED-BSDS/test/223004.jpg
# HED-BSDS/test/97010.jpg
# HED-BSDS/test/206062.jpg
# HED-BSDS/test/104055.jpg
# HED-BSDS/test/101027.jpg
# HED-BSDS/test/198087.jpg
# HED-BSDS/test/226043.jpg
# HED-BSDS/test/51084.jpg
# HED-BSDS/test/48017.jpg
# HED-BSDS/test/249021.jpg
# HED-BSDS/test/268048.jpg
# HED-BSDS/test/181021.jpg
# HED-BSDS/test/243095.jpg
# HED-BSDS/test/71099.jpg
# HED-BSDS/test/253016.jpg
# HED-BSDS/test/87015.jpg
# HED-BSDS/test/317043.jpg
# HED-BSDS/test/102062.jpg
# HED-BSDS/test/41029.jpg
# HED-BSDS/test/185092.jpg
# HED-BSDS/test/71076.jpg
# HED-BSDS/test/8068.jpg
# HED-BSDS/test/335094.jpg
# HED-BSDS/test/77062.jpg
# HED-BSDS/test/35049.jpg
# HED-BSDS/test/103029.jpg
# HED-BSDS/test/201080.jpg
# HED-BSDS/test/246009.jpg
# HED-BSDS/test/250087.jpg
# HED-BSDS/test/163096.jpg
# HED-BSDS/test/230063.jpg
# HED-BSDS/test/106005.jpg
# HED-BSDS/test/112090.jpg
# HED-BSDS/test/2018.jpg
# HED-BSDS/test/70090.jpg
# HED-BSDS/test/118072.jpg
# HED-BSDS/test/220003.jpg
# HED-BSDS/test/376086.jpg
# HED-BSDS/test/196062.jpg
# HED-BSDS/test/196027.jpg
# HED-BSDS/test/302022.jpg
# HED-BSDS/test/388006.jpg
# HED-BSDS/test/101084.jpg
# HED-BSDS/test/247012.jpg
# HED-BSDS/test/179084.jpg
# HED-BSDS/test/384022.jpg
# HED-BSDS/test/94095.jpg
# HED-BSDS/test/156054.jpg
# HED-BSDS/test/257098.jpg
# HED-BSDS/test/112056.jpg
# HED-BSDS/test/105027.jpg
# HED-BSDS/test/384089.jpg
# HED-BSDS/test/6046.jpg
# HED-BSDS/test/69000.jpg
# HED-BSDS/test/388067.jpg
# HED-BSDS/test/33044.jpg
# HED-BSDS/test/388018.jpg
# HED-BSDS/test/43033.jpg
# HED-BSDS/test/20069.jpg
# HED-BSDS/test/347031.jpg
# HED-BSDS/test/123057.jpg
# HED-BSDS/test/288024.jpg
# HED-BSDS/test/326085.jpg
# HED-BSDS/test/365072.jpg
# HED-BSDS/test/141012.jpg
# HED-BSDS/test/253092.jpg
# HED-BSDS/train_pair.lst

# %%
# !head -n 10 HED-BSDS/train_pair.lst > HED-BSDS/val_pair.lst

# %% [markdown]
# ## 1. Explore data

# %%
# load the images dataset
dataRoot = 'HED-BSDS/'
trainPath = dataRoot+'train_pair.lst'
valPath = dataRoot+'val_pair.lst'
testPath = dataRoot+'test.lst'

rootDir = dataRoot
frame = pd.read_csv(trainPath, dtype=str, delimiter=' ')

# check some sample images
idx = 1

# input and target images
inputName = os.path.join(rootDir, frame.iloc[idx, 0])
targetName = os.path.join(rootDir, frame.iloc[idx, 1])

# %%
# process the images
inputImage = np.asarray(Image.open(inputName).convert('RGB'))

crop = 32
inputImage = inputImage[crop:-crop,crop:-crop,:]

plt.figure()
plt.imshow(inputImage)
plt.axis('off')
plt.show()

# %%
# process input and target images
#targetImage = io.imread(targetName)
targetImage = np.asarray(Image.open(targetName).convert('L'))

crop = 32
targetImage = targetImage[crop:-crop,crop:-crop]

targetImage = targetImage/255.0
targetImage = targetImage > 0.0
targetImage = targetImage.astype(np.float32)

plt.figure()
plt.imshow(targetImage,cmap=cm.gray)
plt.axis('off')
plt.show()

# %%
# TODO 1: plot one test image

rootDir = dataRoot
testframe = pd.read_csv(testPath, dtype=str, delimiter=' ')

# %% [markdown]
# ## 2. Prepare the dataset

# %%
# BSDS dataset class for training data
class TrainDataset(Dataset):
    def __init__(self, fileNames, rootDir, 
                 transform=None, target_transform=None):        
        self.rootDir = rootDir
        self.transform = transform
        self.targetTransform = target_transform
        self.frame = pd.read_csv(fileNames, dtype=str, delimiter=' ')

    def __len__(self):
        return len(self.frame)

    def __getitem__(self, idx):
        # input and target images
        inputName = os.path.join(self.rootDir, self.frame.iloc[idx, 0])
        targetName = os.path.join(self.rootDir, self.frame.iloc[idx, 1])

        # process the images
        inputImage = Image.open(inputName).convert('RGB')
        if self.transform is not None:
            inputImage = self.transform(inputImage)

        targetImage = Image.open(targetName).convert('L')
        if self.targetTransform is not None:
            targetImage = self.targetTransform(targetImage)

        return inputImage, targetImage
    
# dataset class for test dataset
class TestDataset(Dataset):
    def __init__(self, fileNames, rootDir, transform=None):
        self.rootDir = rootDir
        self.transform = transform
        self.frame = pd.read_csv(fileNames, dtype=str, delimiter=' ')

    def __len__(self):
        return len(self.frame)

    def __getitem__(self, idx):
        # input and target images
        fname = self.frame.iloc[idx, 0]
        inputName = os.path.join(self.rootDir, fname)

        # process the images
        inputImage = Image.open(inputName).convert('RGB')
        if self.transform is not None:
            inputImage = self.transform(inputImage)

        return inputImage, fname

# %%
std=[0.229, 0.224, 0.225]
mean=[0.485, 0.456, 0.406]

transform = transforms.Compose([
                transforms.Resize((224,224)),
                transforms.ToTensor(),
                transforms.Normalize(mean,std)
            ])
targetTransform = transforms.Compose([
                transforms.Resize((224,224)),
                transforms.ToTensor()
            ])

# %%
nBatch = 1
# create data loaders from dataset
valDataset = TrainDataset(valPath, dataRoot, transform, targetTransform)
trainDataset = TrainDataset(trainPath, dataRoot, transform, targetTransform)

valDataloader = DataLoader(valDataset, batch_size=nBatch, shuffle=False)
trainDataloader = DataLoader(trainDataset, batch_size=nBatch, shuffle=True)

# %% [markdown]
# ## 3. Prepare the model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://download.pytorch.org/models/vgg16-397923af.pth
# !mv vgg16-397923af.pth vgg16.pth

# %%
def weights_init(m):
    classname = m.__class__.__name__
    print (classname)
    if classname.find('Conv2d') != -1:
        init.xavier_uniform(m.weight.data)
        init.constant(m.bias.data, 0.1)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

def transfer_weights(model_from, model_to):
    wf = copy.deepcopy(model_from.state_dict())
    wt = model_to.state_dict()
    for k in wt.keys():
        if not k in wf:
            wf[k] = wt[k]
    model_to.load_state_dict(wf)

def convert_vgg(vgg16):
	net = vgg()
	vgg_items = list(net.state_dict().items())
	vgg16_items = list(vgg16.items())
	pretrain_model = {}
	j = 0
	for k, v in net.state_dict().items():
	    v = vgg16_items[j][1]
	    k = vgg_items[j][0]
	    pretrain_model[k] = v
	    j += 1
	return pretrain_model

class vgg(nn.Module):
    def __init__(self):
        super(vgg, self).__init__()

        # conv1
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=35),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv2
        self.conv2 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/2
            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv3
        self.conv3 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/4
            nn.Conv2d(128, 256, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv4
        self.conv4 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/8
            nn.Conv2d(256, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv5
        self.conv5 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/16
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):

        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)
        conv4 = self.conv4(conv3)
        conv5 = self.conv5(conv4)
        return conv5


class HED(nn.Module):
    def __init__(self):
        super(HED, self).__init__()

        # conv1
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv2
        self.conv2 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/2
            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv3
        self.conv3 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/4
            nn.Conv2d(128, 256, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv4
        self.conv4 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/8
            nn.Conv2d(256, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        # conv5
        self.conv5 = nn.Sequential(
            nn.MaxPool2d(2, stride=2, ceil_mode=True),  # 1/16
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.ReLU(inplace=True),
        )

        self.dsn1 = nn.Conv2d(64, 1, 1)
        self.dsn2 = nn.Conv2d(128, 1, 1)
        self.dsn3 = nn.Conv2d(256, 1, 1)
        self.dsn4 = nn.Conv2d(512, 1, 1)
        self.dsn5 = nn.Conv2d(512, 1, 1)
        self.fuse = nn.Conv2d(5, 1, 1)

    def forward(self, x):
        h = x.size(2)
        w = x.size(3)

        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)
        conv4 = self.conv4(conv3)
        conv5 = self.conv5(conv4)

        ## side output
        d1 = self.dsn1(conv1)
        d2 = F.upsample_bilinear(self.dsn2(conv2), size=(h,w))
        d3 = F.upsample_bilinear(self.dsn3(conv3), size=(h,w))
        d4 = F.upsample_bilinear(self.dsn4(conv4), size=(h,w))
        d5 = F.upsample_bilinear(self.dsn5(conv5), size=(h,w))

        # dsn fusion output
        fuse = self.fuse(torch.cat((d1, d2, d3, d4, d5), 1))
        
        d1 = F.sigmoid(d1)
        d2 = F.sigmoid(d2)
        d3 = F.sigmoid(d3)
        d4 = F.sigmoid(d4)
        d5 = F.sigmoid(d5)
        fuse = F.sigmoid(fuse)

        return d1, d2, d3, d4, d5, fuse

# %%
# initialize the network
net = HED()
net.apply(weights_init)

modelPath = 'vgg16.pth'
pretrained_dict = torch.load(modelPath)
pretrained_dict = convert_vgg(pretrained_dict)

model_dict = net.state_dict()
model_dict.update(pretrained_dict)
net.load_state_dict(model_dict)
net.to('cuda:0')

# %%
# define the optimizer
lr = 1e-4
lrDecay = 1e-1
lrDecayEpoch = {3,5,8,10,12}

fuse_params = list(map(id, net.fuse.parameters()))
conv5_params = list(map(id, net.conv5.parameters()))
base_params = filter(lambda p: id(p) not in conv5_params+fuse_params,
                     net.parameters())

optimizer = torch.optim.SGD([
            {'params': base_params},
            {'params': net.conv5.parameters(), 'lr': lr * 100},
            {'params': net.fuse.parameters(), 'lr': lr * 0.001}
            ], lr=lr, momentum=0.9)

# %% [markdown]
# ## 4. Traing function

# %%
class Trainer(object):
    # init function for class
    def __init__(self, generator, optimizerG, trainDataloader, valDataloader,
                 nBatch=10, out='train', maxEpochs=1, cuda=True, gpuID=0,
                 lrDecayEpochs={}):

        # set the GPU flag
        self.cuda = cuda
        self.gpuID = gpuID
        
        # define an optimizer
        self.optimG = optimizerG
        
        # set the network
        self.generator = generator
        
        # set the data loaders
        self.valDataloader = valDataloader
        self.trainDataloader = trainDataloader
        
        # set output directory
        self.out = out
        if not osp.exists(self.out):
            os.makedirs(self.out)
                
        # set training parameters
        self.epoch = 0
        self.nBatch = nBatch
        self.nepochs = maxEpochs
        self.lrDecayEpochs = lrDecayEpochs
        
        self.gamma = 0.1
        self.valInterval = 500
        self.dispInterval = 100
        self.timeformat = '%Y-%m-%d %H:%M:%S'

    def train(self):
        # function to train network
        for epoch in range(self.epoch, self.nepochs):
            # set function to training mode
            self.generator.train()
            
            # initialize gradients
            self.optimG.zero_grad()
            
            # adjust hed learning rate
            if epoch in self.lrDecayEpochs:
                self.adjustLR()

            # train the network
            losses = []
            lossAcc = 0.0
            for i, sample in enumerate(self.trainDataloader, 0):
                # get the training batch
                data, target = sample
                
                if self.cuda:
                    data, target = data.cuda(self.gpuID), target.cuda(self.gpuID)
                data, target = Variable(data), Variable(target)
                
                # generator forward
                tar = target
                d1, d2, d3, d4, d5, d6 = self.generator(data) 
                
                # compute loss for batch
                loss1 = self.bce2d(d1, tar)
                loss2 = self.bce2d(d2, tar)
                loss3 = self.bce2d(d3, tar)
                loss4 = self.bce2d(d4, tar)
                loss5 = self.bce2d(d5, tar)
                loss6 = self.bce2d(d6, tar)
                
                # all components have equal weightage
                loss = loss1 + loss2 + loss3 + loss4 + loss5 + loss6
                    
                if np.isnan(float(loss.data)):
                    raise ValueError('loss is nan while training')
                
                losses.append(loss)
                lossAcc += loss.data
                    
                # perform backpropogation and update network
                if i%self.nBatch == 0:
                    bLoss = sum(losses)
                
                    bLoss.backward()
                    self.optimG.step()
                    self.optimG.zero_grad()
                
                    losses = []
                    
                # visualize the loss
                if (i+1) % self.dispInterval == 0:
                    timestr = time.strftime(self.timeformat, time.localtime())
                    print("%s epoch: %d iter:%d loss:%.6f"%(timestr, epoch+1, i+1, lossAcc/self.dispInterval))
                    lossAcc = 0.0
                    
                # perform validation every 500 iters
                if (i+1) % self.valInterval == 0:
                    self.val(epoch+1)
                    
            # save model after every epoch
            #torch.save(self.generator.state_dict(), '%s/HED.pth' % (self.out))

    def val(self, epoch):
        # eval model on validation set
        print('Evaluation:')
        
        # convert to test mode
        self.generator.eval()
        
        # save the results
        if os.path.exists(self.out + '/images') == False:
            os.mkdir(self.out + '/images')
        dirName = '%s/images'%(self.out)
        
        # perform test inference
        for i, sample in enumerate(self.valDataloader, 0):            
            # get the test sample
            data, target = sample
            
            if self.cuda:
                data, target = data.cuda(self.gpuID), target.cuda(self.gpuID)
            data, target = Variable(data), Variable(target)
            
            # perform forward computation
            d1, d2, d3, d4, d5, d6 = self.generator.forward(data)
            
            # transform to grayscale images
            d1 = self.grayTrans(self.crop(d1))
            d2 = self.grayTrans(self.crop(d2))
            d3 = self.grayTrans(self.crop(d3))
            d4 = self.grayTrans(self.crop(d4))
            d5 = self.grayTrans(self.crop(d5))
            d6 = self.grayTrans(self.crop(d6))
            tar = self.grayTrans(self.crop(target))
            
            d1.save('%s/sample%d1.png' % (dirName, i))
            d2.save('%s/sample%d2.png' % (dirName, i))
            d3.save('%s/sample%d3.png' % (dirName, i))
            d4.save('%s/sample%d4.png' % (dirName, i))
            d5.save('%s/sample%d5.png' % (dirName, i))
            d6.save('%s/sample%d6.png' % (dirName, i))
            tar.save('%s/sample%dT.png' % (dirName, i))
            
        print('evaluate done')
        self.generator.train()
    
    # function to crop the padding pixels
    def crop(self, d):
        d_h, d_w = d.size()[2:4]
        g_h, g_w = d_h-64, d_w-64
        d1 = d[:, :, int(math.floor((d_h - g_h)/2.0)):int(math.floor((d_h - g_h)/2.0)) + g_h, int(math.floor((d_w - g_w)/2.0)):int(math.floor((d_w - g_w)/2.0)) + g_w]
        return d1
    
    def _assertNoGrad(self, variable):
        assert not variable.requires_grad, \
        "nn criterions don't compute the gradient w.r.t. targets - please " \
        "mark these variables as volatile or not requiring gradients"

    # binary cross entropy loss in 2D
    def bce2d(self, input, target):
        n, c, h, w = input.size()
    
        # assert(max(target) == 1)
        
        log_p = input.transpose(1, 2).transpose(2, 3).contiguous().view(1, -1)
        target_t = target.transpose(1, 2).transpose(2, 3).contiguous().view(1, -1)
        
        target_trans = target_t.clone()
        pos_index = (target_t >0)
        neg_index = (target_t ==0)
        target_trans[pos_index] = 1
        target_trans[neg_index] = 0

        pos_index = pos_index.data.cpu().numpy().astype(bool)
        neg_index = neg_index.data.cpu().numpy().astype(bool)

        weight = torch.Tensor(log_p.size()).fill_(0)
        weight = weight.numpy()
        pos_num = pos_index.sum()
        neg_num = neg_index.sum()
        sum_num = pos_num + neg_num
        weight[pos_index] = neg_num*1.0 / sum_num
        weight[neg_index] = pos_num*1.0 / sum_num

        weight = torch.from_numpy(weight)
        weight = weight.cuda()
        loss = F.binary_cross_entropy(log_p, target_t, weight, size_average=True)
        
        return loss

    def grayTrans(self, img):
        img = img.data.cpu().numpy()[0][0]*255.0
        img = (img).astype(np.uint8)
        img = Image.fromarray(img, 'L')
        return img

    # utility functions to set the learning rate
    def adjustLR(self):
        for param_group in self.optimG.param_groups:
            param_group['lr'] *= self.gamma

# %%
# initialize trainer class
trainer = Trainer(net, optimizer, trainDataloader, valDataloader, 
                  nBatch=nBatch, maxEpochs=15, cuda=True, gpuID=0,
                  lrDecayEpochs=lrDecayEpoch)

# train the network
trainer.train()

# %% [markdown]
# ## 4. Test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
testDataset = TestDataset(testPath, dataRoot, transform)
testDataloader = DataLoader(testDataset, batch_size=1)

# %%
def grayTrans(img):
    img = img.numpy()[0][0]*255.0
    img = (img).astype(np.uint8)
    return img

# %%
def plotResults(images, size):
    pylab.rcParams['figure.figsize'] = size, size
    
    nPlots = len(images)
    titles = ['org', 'HED', 'S1', 'S2', 'S3', 'S4']
    plt.figure()
    for i in range(0, len(images)):
        s=plt.subplot(1,nPlots,i+1)
        plt.imshow(images[i], cmap = cm.Greys_r)
        s.set_xticklabels([])
        s.set_yticklabels([])
        s.yaxis.set_ticks_position('none')
        s.xaxis.set_ticks_position('none')
        s.set_title(titles[i],fontsize=35)
    plt.tight_layout()
    plt.show()

# %%
if not os.path.isdir('test'):
  os.makedirs('test')
nVisualize = 10
for i, sample in enumerate(testDataloader):
    # get input sample image
    inp, fname = sample
    inp = Variable(inp.cuda())
    
    # perform forward computation
    s1,s2,s3,s4,s5,s6 = net.forward(inp)
    
    # convert back to numpy arrays
    out = []
    out.append(grayTrans(s6.data.cpu()))
    out.append(grayTrans(s1.data.cpu()))
    out.append(grayTrans(s2.data.cpu()))
    out.append(grayTrans(s3.data.cpu()))
    out.append(grayTrans(s4.data.cpu()))

    print(fname)
    img = Image.fromarray(out[0], 'L')
    img.save(fname[0].split('.',1)[0]+'.png')

    # visualize every 10th image
    if i%nVisualize == 0:
        plotResults([Image.open(
            os.path.join(dataRoot, 'test', fname[0].split(os.sep)[1])
            ).convert('RGB')] + out, 25)
