# %%
import torch
import torchvision.models as models
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda
from torch import nn

# %% [markdown]
# # Full Pipeline
# ## 4 Steps to training Deep Learning Models
#
# 1. Data
# 2. Model
# 3. objective function; loss function
# 4. optimizer

# %% [markdown]
# Before all else, if you have an available GPU, get it ready!

# %% [markdown]
# Get the data ready by loading the [MNIST](https://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html#torchvision.datasets.MNIST) dataset.

# %% [markdown]
# Declare and initialize your Neural net.
# Note that MNIST images are of size $ 28 \times 28$ each.

# %% [markdown]
# Set the objective/loss function

# %% [markdown]
# Set the optimizer, and define the hyperparameters to use (Learning rate, Batch size, epochs)

# %% [markdown]
# Train the model!

# %% [markdown]
# Save the Model and Load it!

# %% [markdown]
# [Optional]
#
# When finished all above, try...
# - Altering the network structure to see what happens (number of layers, hidden size)
# - Diverse learning rates, epoch, batch size
# - Different [optimizers](https://pytorch.org/docs/stable/optim.html)
#
# What happens when you alter the network and or hyperparameters?
